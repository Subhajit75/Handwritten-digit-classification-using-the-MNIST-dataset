# %% [markdown]
# # **Handwritten digits recognition using Mnist Datasets**
#
# >

# %%
# Out:
# Mounted at /content/drive

# %%
# %matplotlib inline

import numpy as np
import matplotlib.pyplot as plt
import torch
from tqdm.notebook import tqdm

# %%
from torchvision import datasets, transforms
mnist_train = datasets.MNIST(root="./datasets", train=True, transform=transforms.ToTensor(), download=True)
mnist_test = datasets.MNIST(root="./datasets", train=False, transform=transforms.ToTensor(), download=True)

# %%
print("Number of MNIST training examples: {}".format(len(mnist_train)))
print("Number of MNIST test examples: {}".format(len(mnist_test)))
# Out:
# Number of MNIST training examples: 60000
# Number of MNIST test examples: 10000

# %%
# Pick out the 4th (0-indexed) example from the training set
#label=7
#image, label = mnist_train[4[0]]

label_to_plot = 7
filtered_indices = [i for i, (image, label) in enumerate(mnist_train) if label == label_to_plot]

# Pick out the first example (0-indexed) from the filtered dataset
index_to_plot = 0  # Index of the first example
image_to_plot, label_to_plot = mnist_train[filtered_indices[index_to_plot]]


# Plot the image
print("Default image shape: {}".format(image_to_plot.shape))
image_to_plot = image_to_plot.reshape([28,28])
print("Reshaped image shape: {}".format(image_to_plot.shape))
plt.imshow(image_to_plot, cmap="gray")

# Print the label
print("The label for this image: {}".format(label_to_plot))
# Out:
# Default image shape: torch.Size([1, 28, 28])
# Reshaped image shape: torch.Size([28, 28])
# The label for this image: 7

# %%
import matplotlib.pyplot as plt

# Define the label you want to plot (e.g., '7')
label_to_plot = 7

# Filter the test set to get indices of all images with the desired label
filtered_indices_test = [i for i, (image, label) in enumerate(mnist_test) if label == label_to_plot]

# Select the first example from the filtered test set
index_to_plot = 0  # Index of the first example
image_to_plot, label_to_plot = mnist_test[filtered_indices_test[index_to_plot]]

# Print the default image shape
print("Default image shape: {}".format(image_to_plot.shape))

# Reshape the image to 28x28
image_to_plot = image_to_plot.reshape([28, 28])
print("Reshaped image shape: {}".format(image_to_plot.shape))

# Plot the image
plt.imshow(image_to_plot, cmap="gray")
plt.show()

# Print the label for the plotted image
print("The label for this image: {}".format(label_to_plot))
# Out:
# Default image shape: torch.Size([1, 28, 28])
# Reshaped image shape: torch.Size([28, 28])
# The label for this image: 7

# %%
# Pick out the 4th (0-indexed) example from the training set
#label=8
#image, label = mnist_train[4[0]]

label_to_plot = 8
filtered_indices = [i for i, (image, label) in enumerate(mnist_train) if label == label_to_plot]

# Pick out the first example (0-indexed) from the filtered dataset
index_to_plot = 0  # Index of the first example
image_to_plot, label_to_plot = mnist_train[filtered_indices[index_to_plot]]


# Plot the image
print("Default image shape: {}".format(image_to_plot.shape))
image_to_plot = image_to_plot.reshape([28,28])
print("Reshaped image shape: {}".format(image_to_plot.shape))
plt.imshow(image_to_plot, cmap="gray")

# Print the label
print("The label for this image: {}".format(label_to_plot))
# Out:
# Default image shape: torch.Size([1, 28, 28])
# Reshaped image shape: torch.Size([28, 28])
# The label for this image: 8

# %%
import matplotlib.pyplot as plt

# Define the label you want to plot (e.g., '8')
label_to_plot = 8

# Filter the test set to get indices of all images with the desired label
filtered_indices_test = [i for i, (image, label) in enumerate(mnist_test) if label == label_to_plot]

# Select the first example from the filtered test set
index_to_plot = 0  # Index of the first example
image_to_plot, label_to_plot = mnist_test[filtered_indices_test[index_to_plot]]

# Print the default image shape
print("Default image shape: {}".format(image_to_plot.shape))

# Reshape the image to 28x28
image_to_plot = image_to_plot.reshape([28, 28])
print("Reshaped image shape: {}".format(image_to_plot.shape))

# Plot the image
plt.imshow(image_to_plot, cmap="gray")
plt.show()

# Print the label for the plotted image
print("The label for this image: {}".format(label_to_plot))
# Out:
# Default image shape: torch.Size([1, 28, 28])
# Reshaped image shape: torch.Size([28, 28])
# The label for this image: 8

# %%
# Pick out the 4th (0-indexed) example from the training set
#label=5
#image, label = mnist_train[4[0]]

label_to_plot = 5
filtered_indices = [i for i, (image, label) in enumerate(mnist_train) if label == label_to_plot]

# Pick out the first example (0-indexed) from the filtered dataset
index_to_plot = 0  # Index of the first example
image_to_plot, label_to_plot = mnist_train[filtered_indices[index_to_plot]]


# Plot the image
print("Default image shape: {}".format(image_to_plot.shape))
image_to_plot = image_to_plot.reshape([28,28])
print("Reshaped image shape: {}".format(image_to_plot.shape))
plt.imshow(image_to_plot, cmap="gray")

# Print the label
print("The label for this image: {}".format(label_to_plot))
# Out:
# Default image shape: torch.Size([1, 28, 28])
# Reshaped image shape: torch.Size([28, 28])
# The label for this image: 5

# %%
import matplotlib.pyplot as plt

# Define the label you want to plot (e.g., '5')
label_to_plot = 5

# Filter the test set to get indices of all images with the desired label
filtered_indices_test = [i for i, (image, label) in enumerate(mnist_test) if label == label_to_plot]

# Select the first example from the filtered test set
index_to_plot = 0  # Index of the first example
image_to_plot, label_to_plot = mnist_test[filtered_indices_test[index_to_plot]]

# Print the default image shape
print("Default image shape: {}".format(image_to_plot.shape))

# Reshape the image to 28x28
image_to_plot = image_to_plot.reshape([28, 28])
print("Reshaped image shape: {}".format(image_to_plot.shape))

# Plot the image
plt.imshow(image_to_plot, cmap="gray")
plt.show()

# Print the label for the plotted image
print("The label for this image: {}".format(label_to_plot))
# Out:
# Default image shape: torch.Size([1, 28, 28])
# Reshaped image shape: torch.Size([28, 28])
# The label for this image: 5

# %%
# Pick out the 4th (0-indexed) example from the training set
#label=6
#image, label = mnist_train[4[0]]

label_to_plot = 6
filtered_indices = [i for i, (image, label) in enumerate(mnist_train) if label == label_to_plot]

# Pick out the first example (0-indexed) from the filtered dataset
index_to_plot = 0  # Index of the first example
image_to_plot, label_to_plot = mnist_train[filtered_indices[index_to_plot]]


# Plot the image
print("Default image shape: {}".format(image_to_plot.shape))
image_to_plot = image_to_plot.reshape([28,28])
print("Reshaped image shape: {}".format(image_to_plot.shape))
plt.imshow(image_to_plot, cmap="gray")

# Print the label
print("The label for this image: {}".format(label_to_plot))
# Out:
# Default image shape: torch.Size([1, 28, 28])
# Reshaped image shape: torch.Size([28, 28])
# The label for this image: 6

# %%
import matplotlib.pyplot as plt

# Define the label you want to plot (e.g., '6')
label_to_plot = 6

# Filter the test set to get indices of all images with the desired label
filtered_indices_test = [i for i, (image, label) in enumerate(mnist_test) if label == label_to_plot]

# Select the first example from the filtered test set
index_to_plot = 0  # Index of the first example
image_to_plot, label_to_plot = mnist_test[filtered_indices_test[index_to_plot]]

# Print the default image shape
print("Default image shape: {}".format(image_to_plot.shape))

# Reshape the image to 28x28
image_to_plot = image_to_plot.reshape([28, 28])
print("Reshaped image shape: {}".format(image_to_plot.shape))

# Plot the image
plt.imshow(image_to_plot, cmap="gray")
plt.show()

# Print the label for the plotted image
print("The label for this image: {}".format(label_to_plot))
# Out:
# Default image shape: torch.Size([1, 28, 28])
# Reshaped image shape: torch.Size([28, 28])
# The label for this image: 6

# %%
# Pick out the 4th (0-indexed) example from the training set
#label=2
#image, label = mnist_train[4[0]]

label_to_plot = 2
filtered_indices = [i for i, (image, label) in enumerate(mnist_train) if label == label_to_plot]

# Pick out the first example (0-indexed) from the filtered dataset
index_to_plot = 0  # Index of the first example
image_to_plot, label_to_plot = mnist_train[filtered_indices[index_to_plot]]


# Plot the image
print("Default image shape: {}".format(image_to_plot.shape))
image_to_plot = image_to_plot.reshape([28,28])
print("Reshaped image shape: {}".format(image_to_plot.shape))
plt.imshow(image_to_plot, cmap="gray")

# Print the label
print("The label for this image: {}".format(label_to_plot))
# Out:
# Default image shape: torch.Size([1, 28, 28])
# Reshaped image shape: torch.Size([28, 28])
# The label for this image: 2

# %%
import matplotlib.pyplot as plt

# Define the label you want to plot (e.g., '2')
label_to_plot = 2

# Filter the test set to get indices of all images with the desired label
filtered_indices_test = [i for i, (image, label) in enumerate(mnist_test) if label == label_to_plot]

# Select the first example from the filtered test set
index_to_plot = 0  # Index of the first example
image_to_plot, label_to_plot = mnist_test[filtered_indices_test[index_to_plot]]

# Print the default image shape
print("Default image shape: {}".format(image_to_plot.shape))

# Reshape the image to 28x28
image_to_plot = image_to_plot.reshape([28, 28])
print("Reshaped image shape: {}".format(image_to_plot.shape))

# Plot the image
plt.imshow(image_to_plot, cmap="gray")
plt.show()

# Print the label for the plotted image
print("The label for this image: {}".format(label_to_plot))
# Out:
# Default image shape: torch.Size([1, 28, 28])
# Reshaped image shape: torch.Size([28, 28])
# The label for this image: 2

# %%
# Pick out the 4th (0-indexed) example from the training set
#label=3
#image, label = mnist_train[4[0]]

label_to_plot = 3
filtered_indices = [i for i, (image, label) in enumerate(mnist_train) if label == label_to_plot]

# Pick out the first example (0-indexed) from the filtered dataset
index_to_plot = 0  # Index of the first example
image_to_plot, label_to_plot = mnist_train[filtered_indices[index_to_plot]]


# Plot the image
print("Default image shape: {}".format(image_to_plot.shape))
image_to_plot = image_to_plot.reshape([28,28])
print("Reshaped image shape: {}".format(image_to_plot.shape))
plt.imshow(image_to_plot, cmap="gray")

# Print the label
print("The label for this image: {}".format(label_to_plot))
# Out:
# Default image shape: torch.Size([1, 28, 28])
# Reshaped image shape: torch.Size([28, 28])
# The label for this image: 3

# %%
import matplotlib.pyplot as plt

# Define the label you want to plot (e.g., '3')
label_to_plot = 3

# Filter the test set to get indices of all images with the desired label
filtered_indices_test = [i for i, (image, label) in enumerate(mnist_test) if label == label_to_plot]

# Select the first example from the filtered test set
index_to_plot = 0  # Index of the first example
image_to_plot, label_to_plot = mnist_test[filtered_indices_test[index_to_plot]]

# Print the default image shape
print("Default image shape: {}".format(image_to_plot.shape))

# Reshape the image to 28x28
image_to_plot = image_to_plot.reshape([28, 28])
print("Reshaped image shape: {}".format(image_to_plot.shape))

# Plot the image
plt.imshow(image_to_plot, cmap="gray")
plt.show()

# Print the label for the plotted image
print("The label for this image: {}".format(label_to_plot))
# Out:
# Default image shape: torch.Size([1, 28, 28])
# Reshaped image shape: torch.Size([28, 28])
# The label for this image: 3

# %%
# Pick out the 4th (0-indexed) example from the training set
#label=4
#image, label = mnist_train[4[0]]

label_to_plot = 4
filtered_indices = [i for i, (image, label) in enumerate(mnist_train) if label == label_to_plot]

# Pick out the first example (0-indexed) from the filtered dataset
index_to_plot = 0  # Index of the first example
image_to_plot, label_to_plot = mnist_train[filtered_indices[index_to_plot]]


# Plot the image
print("Default image shape: {}".format(image_to_plot.shape))
image_to_plot = image_to_plot.reshape([28,28])
print("Reshaped image shape: {}".format(image_to_plot.shape))
plt.imshow(image_to_plot, cmap="gray")

# Print the label
print("The label for this image: {}".format(label_to_plot))
# Out:
# Default image shape: torch.Size([1, 28, 28])
# Reshaped image shape: torch.Size([28, 28])
# The label for this image: 4

# %%
import matplotlib.pyplot as plt

# Define the label you want to plot (e.g., '4')
label_to_plot = 4

# Filter the test set to get indices of all images with the desired label
filtered_indices_test = [i for i, (image, label) in enumerate(mnist_test) if label == label_to_plot]

# Select the first example from the filtered test set
index_to_plot = 0  # Index of the first example
image_to_plot, label_to_plot = mnist_test[filtered_indices_test[index_to_plot]]

# Print the default image shape
print("Default image shape: {}".format(image_to_plot.shape))

# Reshape the image to 28x28
image_to_plot = image_to_plot.reshape([28, 28])
print("Reshaped image shape: {}".format(image_to_plot.shape))

# Plot the image
plt.imshow(image_to_plot, cmap="gray")
plt.show()

# Print the label for the plotted image
print("The label for this image: {}".format(label_to_plot))
# Out:
# Default image shape: torch.Size([1, 28, 28])
# Reshaped image shape: torch.Size([28, 28])
# The label for this image: 4

# %%
# Pick out the 4th (0-indexed) example from the training set
#label=9
#image, label = mnist_train[4[0]]

label_to_plot = 9
filtered_indices = [i for i, (image, label) in enumerate(mnist_train) if label == label_to_plot]

# Pick out the first example (0-indexed) from the filtered dataset
index_to_plot = 0  # Index of the first example
image_to_plot, label_to_plot = mnist_train[filtered_indices[index_to_plot]]


# Plot the image
print("Default image shape: {}".format(image_to_plot.shape))
image_to_plot = image_to_plot.reshape([28,28])
print("Reshaped image shape: {}".format(image_to_plot.shape))
plt.imshow(image_to_plot, cmap="gray")

# Print the label
print("The label for this image: {}".format(label_to_plot))
# Out:
# Default image shape: torch.Size([1, 28, 28])
# Reshaped image shape: torch.Size([28, 28])
# The label for this image: 9

# %%
import matplotlib.pyplot as plt

# Define the label you want to plot (e.g., '9')
label_to_plot = 9

# Filter the test set to get indices of all images with the desired label
filtered_indices_test = [i for i, (image, label) in enumerate(mnist_test) if label == label_to_plot]

# Select the first example from the filtered test set
index_to_plot = 0  # Index of the first example
image_to_plot, label_to_plot = mnist_test[filtered_indices_test[index_to_plot]]

# Print the default image shape
print("Default image shape: {}".format(image_to_plot.shape))

# Reshape the image to 28x28
image_to_plot = image_to_plot.reshape([28, 28])
print("Reshaped image shape: {}".format(image_to_plot.shape))

# Plot the image
plt.imshow(image_to_plot, cmap="gray")
plt.show()

# Print the label for the plotted image
print("The label for this image: {}".format(label_to_plot))
# Out:
# Default image shape: torch.Size([1, 28, 28])
# Reshaped image shape: torch.Size([28, 28])
# The label for this image: 9

# %%
# Pick out the 4th (0-indexed) example from the training set
#label=1
#image, label = mnist_train[4[0]]

label_to_plot = 1
filtered_indices = [i for i, (image, label) in enumerate(mnist_train) if label == label_to_plot]

# Pick out the first example (0-indexed) from the filtered dataset
index_to_plot = 0  # Index of the first example
image_to_plot, label_to_plot = mnist_train[filtered_indices[index_to_plot]]


# Plot the image
print("Default image shape: {}".format(image_to_plot.shape))
image_to_plot = image_to_plot.reshape([28,28])
print("Reshaped image shape: {}".format(image_to_plot.shape))
plt.imshow(image_to_plot, cmap="gray")

# Print the label
print("The label for this image: {}".format(label_to_plot))
# Out:
# Default image shape: torch.Size([1, 28, 28])
# Reshaped image shape: torch.Size([28, 28])
# The label for this image: 1

# %%
import matplotlib.pyplot as plt

# Define the label you want to plot (e.g., '1')
label_to_plot = 1

# Filter the test set to get indices of all images with the desired label
filtered_indices_test = [i for i, (image, label) in enumerate(mnist_test) if label == label_to_plot]

# Select the first example from the filtered test set
index_to_plot = 0  # Index of the first example
image_to_plot, label_to_plot = mnist_test[filtered_indices_test[index_to_plot]]

# Print the default image shape
print("Default image shape: {}".format(image_to_plot.shape))

# Reshape the image to 28x28
image_to_plot = image_to_plot.reshape([28, 28])
print("Reshaped image shape: {}".format(image_to_plot.shape))

# Plot the image
plt.imshow(image_to_plot, cmap="gray")
plt.show()

# Print the label for the plotted image
print("The label for this image: {}".format(label_to_plot))
# Out:
# Default image shape: torch.Size([1, 28, 28])
# Reshaped image shape: torch.Size([28, 28])
# The label for this image: 1

# %%
# Pick out the 4th (0-indexed) example from the training set
#label= 0
#image, label = mnist_train[4[0]]

label_to_plot = 0
filtered_indices = [i for i, (image, label) in enumerate(mnist_train) if label == label_to_plot]

# Pick out the first example (0-indexed) from the filtered dataset
index_to_plot = 0  # Index of the first example
image_to_plot, label_to_plot = mnist_train[filtered_indices[index_to_plot]]


# Plot the image
print("Default image shape: {}".format(image_to_plot.shape))
image_to_plot = image_to_plot.reshape([28,28])
print("Reshaped image shape: {}".format(image_to_plot.shape))
plt.imshow(image_to_plot, cmap="gray")

# Print the label
print("The label for this image: {}".format(label_to_plot))
# Out:
# Default image shape: torch.Size([1, 28, 28])
# Reshaped image shape: torch.Size([28, 28])
# The label for this image: 0

# %%
import matplotlib.pyplot as plt

# Define the label you want to plot (e.g., '0')
label_to_plot = 0

# Filter the test set to get indices of all images with the desired label
filtered_indices_test = [i for i, (image, label) in enumerate(mnist_test) if label == label_to_plot]

# Select the first example from the filtered test set
index_to_plot = 0  # Index of the first example
image_to_plot, label_to_plot = mnist_test[filtered_indices_test[index_to_plot]]

# Print the default image shape
print("Default image shape: {}".format(image_to_plot.shape))

# Reshape the image to 28x28
image_to_plot = image_to_plot.reshape([28, 28])
print("Reshaped image shape: {}".format(image_to_plot.shape))

# Plot the image
plt.imshow(image_to_plot, cmap="gray")
plt.show()

# Print the label for the plotted image
print("The label for this image: {}".format(label_to_plot))
# Out:
# Default image shape: torch.Size([1, 28, 28])
# Reshaped image shape: torch.Size([28, 28])
# The label for this image: 0

# %%
from collections import Counter

# Count the number of occurrences for each label in the training set
train_label_counts = Counter([label for _, label in mnist_train])

# Count the number of occurrences for each label in the test set
test_label_counts = Counter([label for _, label in mnist_test])

# Print the counts
print("Training set label counts:")
for label, count in sorted(train_label_counts.items()):
    print(f"Label {label}: {count} images")

print("\nTest set label counts:")
for label, count in sorted(test_label_counts.items()):
    print(f"Label {label}: {count} images")
# Out:
# Training set label counts:
# Label 0: 5923 images
# Label 1: 6742 images
# Label 2: 5958 images
# Label 3: 6131 images
# Label 4: 5842 images
# Label 5: 5421 images
# Label 6: 5918 images
# Label 7: 6265 images
# Label 8: 5851 images
# Label 9: 5949 images
#
# Test set label counts:
# Label 0: 980 images
# Label 1: 1135 images
# Label 2: 1032 images
# Label 3: 1010 images
# Label 4: 982 images
# Label 5: 892 images
# Label 6: 958 images
# Label 7: 1028 images
# Label 8: 974 images
# Label 9: 1009 images

# %%
train_loader = torch.utils.data.DataLoader(mnist_train, batch_size=10, shuffle=True)
test_loader = torch.utils.data.DataLoader(mnist_test, batch_size=10, shuffle=False)

# %%
data_train_iter = iter(train_loader)
#images, labels = data_train_iter.next()
for images, labels in data_train_iter:

  print("Shape of the minibatch of images: {}".format(images.shape))
  print("Shape of the minibatch of labels: {}".format(labels.shape))
# Out:
# Streaming output truncated to the last 5000 lines.
# Shape of the minibatch of images: torch.Size([10, 1, 28, 28])
# Shape of the minibatch of labels: torch.Size([10])
# Shape of the minibatch of images: torch.Size([10, 1, 28, 28])
# Shape of the minibatch of labels: torch.Size([10])
# Shape of the minibatch of images: torch.Size([10, 1, 28, 28])
# Shape of the minibatch of labels: torch.Size([10])
# Shape of the minibatch of images: torch.Size([10, 1, 28, 28])
# Shape of the minibatch of labels: torch.Size([10])
# Shape of the minibatch of images: torch.Size([10, 1, 28, 28])
# Shape of the minibatch of labels: torch.Size([10])
# Shape of the minibatch of images: torch.Size([10, 1, 28, 28])
# Shape of the minibatch of labels: torch.Size([10])
# Shape of the minibatch of images: torch.Size([10, 1, 28, 28])
# Shape of the minibatch of labels: torch.Size([10])
# Shape of the minibatch of images: torch.Size([10, 1, 28, 28])
# Shape of the minibatch of labels: torch.Size([10])
# ...

# %%
x = images.view(-1, 28*28)
print("The shape of input x: {}".format(x.shape))
# Out:
# The shape of input x: torch.Size([10, 784])

# %%
# Randomly initialize weights W
W = torch.randn(784, 10)/np.sqrt(784)
W.requires_grad_()

# Initialize bias b as 0s
b = torch.zeros(10, requires_grad=True)

# %%
# Linear transformation with W and b
y = torch.matmul(x, W) + b

# %%
print(y[0,:])
# Out:
# tensor([-0.3579,  0.5184, -0.2923, -0.0847, -0.1691, -0.0802,  0.0289, -0.3582,
#          0.7660, -0.2817], grad_fn=<SliceBackward0>)

# %%
# Option 1: Softmax to probabilities from equation
py_eq = torch.exp(y) / torch.sum(torch.exp(y), dim=1, keepdim=True)
print("py[0] from equation: {}".format(py_eq[0]))

# Option 2: Softmax to probabilities with torch.nn.functional
import torch.nn.functional as F
py = F.softmax(y, dim=1)
print("py[0] with torch.nn.functional.softmax: {}".format(py[0]))
# Out:
# py[0] from equation: tensor([0.0669, 0.1608, 0.0715, 0.0880, 0.0808, 0.0884, 0.0985, 0.0669, 0.2060,
#         0.0722], grad_fn=<SelectBackward0>)
# py[0] with torch.nn.functional.softmax: tensor([0.0669, 0.1608, 0.0715, 0.0880, 0.0808, 0.0884, 0.0985, 0.0669, 0.2060,
#         0.0722], grad_fn=<SelectBackward0>)

# %%
print(labels.shape)
# Out:
# torch.Size([10])

# %%
# Cross-entropy loss from equation
cross_entropy_eq = torch.mean(-torch.log(py_eq)[range(labels.shape[0]),labels])
print("cross entropy from equation: {}".format(cross_entropy_eq))

# Option 2: cross-entropy loss with torch.nn.functional
cross_entropy = F.cross_entropy(y, labels)
print("cross entropy with torch.nn.functional.cross_entropy: {}".format(cross_entropy))
# Out:
# cross entropy from equation: 2.235609531402588
# cross entropy with torch.nn.functional.cross_entropy: 2.235609769821167

# %%
# Optimizer
optimizer = torch.optim.SGD([W,b], lr=0.1)

# %%
cross_entropy.backward()

# %%
b.grad # (b new = b old - lr*grad)
# Out:
# tensor([ 0.0862,  0.0566,  0.0083, -0.2114, -0.0322,  0.0841,  0.0812, -0.0307,
#         -0.1284,  0.0864])

# %%
optimizer.step()

# %%
b
# Out:
# tensor([-0.0086, -0.0057, -0.0008,  0.0211,  0.0032, -0.0084, -0.0081,  0.0031,
#          0.0128, -0.0086], requires_grad=True)

# %%
print("b.grad before zero_grad(): {}".format(b.grad))
optimizer.zero_grad()
print("b.grad after zero_grad(): {}".format(b.grad))
# Out:
# b.grad before zero_grad(): tensor([ 0.0862,  0.0566,  0.0083, -0.2114, -0.0322,  0.0841,  0.0812, -0.0307,
#         -0.1284,  0.0864])
# b.grad after zero_grad(): None

# %%
# Iterate through train set minibatchs
for epoch in range(10):
  for images, labels in tqdm(train_loader):
    # Zero out the gradients
    optimizer.zero_grad()

    # Forward pass
    x = images.view(-1, 28*28)
    y = torch.matmul(x, W) + b
    cross_entropy = F.cross_entropy(y, labels)
    # Backward pass
    cross_entropy.backward()
    optimizer.step()
# Out:
# ...
#   0%|          | 0/6000 [00:00<?, ?it/s]

# %%
correct = 0
total = len(mnist_test)

with torch.no_grad():
    # Iterate through test set minibatchs
    for images, labels in tqdm(test_loader):
        # Forward pass
        x = images.view(-1, 28*28)
        y = torch.matmul(x, W) + b

        predictions = torch.argmax(y, dim=1)
        correct += torch.sum((predictions == labels).float())

print('Test accuracy: {}'.format(correct/total))
# Out:
#   0%|          | 0/1000 [00:00<?, ?it/s]
# Test accuracy: 0.9228000044822693

# %%
# Get weights
fig, ax = plt.subplots(1, 10, figsize=(20, 2))

for digit in range(10):
    ax[digit].imshow(W[:,digit].detach().view(28,28), cmap='gray')
